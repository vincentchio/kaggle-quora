# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
from nltk.stem import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.metrics import log_loss
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

# %%
train_df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
dev_train_df, dev_test_df = train_test_split(train_df, test_size=0.31, random_state=0)

# %%
print "Duplicate percentage:", np.average(train_df['is_duplicate'])
# Out:
# Duplicate percentage: 0.369197853026

# %%
qids = pd.Series(train_df['qid1'].tolist() + train_df['qid2'].tolist())

# %%
train_qs = pd.Series(train_df['question1'].tolist() + train_df['question2'].tolist()).astype(str)

# %%
print "Total question count:", len(qids.unique())
print "Duplicate question count:", sum(qids.value_counts() > 1)
# Out:
#  Total question count: 537933
# Duplicate question count: 111780

# %%
print "Fraction contains math:", np.average(train_qs.apply(lambda q: '[math]' in q))
# Out:
# Fraction contains math: 0.00117366247001

# %% [markdown]
# ## Baseline

# %%
log_loss(dev_test_df['is_duplicate'], [np.average(dev_train_tf['is_duplicate'])] * dev_test_df.shape[0])
# Out:
# 0.65923423793715774

# %% [markdown]
# ## Preprocessing

# %%
tokenizer = TreebankWordTokenizer()
lemmatizer = WordNetLemmatizer()
stemmer = SnowballStemmer(language='english')

DIGIT_LETTER_RE = re.compile(r"([a-zA-Z]+)[\.\-]*(\d+)")
MATH_RE = re.compile(r'\[math\].*?\[\/math\]')
DIGIT_COMMA_RE = re.compile(r'(\d+),(?=000)')
LETTER_LETTER_RE = re.compile(r"([a-zA-Z]+)[/\-](?=[a-zA-Z]+)")

def tokenize(text):
    return " ".join([stemmer.stem(lemmatizer.lemmatize(token)) for token in tokenizer.tokenize(text)])

def clean_unicode(text):
    return ''.join([c for c in text if ord(c) <= 127])

def split_digit_letter(text):
    """ ABC123 -> ABC 123
    """
    return DIGIT_LETTER_RE.sub(r'\1 \2', text)

def replace_math_syntax(text):
    """ [math]a=b+c[/math] -> _math_
    """
    return MATH_RE.sub('_math_', text)

def merge_digit_comma(text):
    """ 15,000 > 15000
    """
    return DIGIT_COMMA_RE.sub(r'\1', text)

def split_letter_letter(text):
    """ mind-blowing -> mind blowing
    improvement/clarification -> improvement clarification
    """
    return LETTER_LETTER_RE.sub(r'\1 ', text)

def load_replace_words_re():
    replace_words_re = []
    with open('data/word_replace.csv') as f:
        for line in f:
            word, replaced_word = line[:-1].split(',')
            replace_words_re.append((re.compile(r"(\W|^)%s(?=\W|$)" % word), r'\1%s' % replaced_word))
        
    return replace_words_re + [
        (re.compile(r'₹'), ' rupee '),
        (re.compile(r'’'), "'"),
        (re.compile(r'∧'), '^')
    ]

REPLACE_WORDS_RE = load_replace_words_re()
def replace_words(text):
    for regex, replaced_word in REPLACE_WORDS_RE:
        text = regex.sub(replaced_word, text)
    return text

def preprocess_text(text):
    text = replace_math_syntax(text)
    text = replace_words(text)
    text = merge_digit_comma(text)
    text = split_digit_letter(text)
    text = split_letter_letter(text)
    text = clean_unicode(text)
    return tokenize(text)

# %%
split_letter_letter('Vinyl-Leather-Rubber')
# Out:
# 'Vinyl Leather Rubber'

# %%
train_df['cleaned_question1'] = train_df['question1'].apply(lambda text: preprocess_text(text))

# %%
train_df['cleaned_question1']
# Out:
# 0         what is the step by step guid to invest in sha...
# 1         what is the stori of kohinoor ( koh i-noor ) d...
# 2         how can i increas the speed of my internet con...
# 3           whi am i mental veri lone ? how can i solv it ?
# 4         which one dissolv in water quik sugar , salt ,...
# 5         astrolog : i am a capricorn sun cap moon and c...
# 6                                      should i buy tiago ?
# 7                           how can i be a good geologist ?
# 8                              when do you use instead of ?
# 9         motorola ( compani ) : can i hack my charter m...
# 10        method to find separ of slit use fresnel bipri...
# 11               how do i read and find my youtub comment ?
# 12                     what can make physic easi to learn ?
# 13                  what wa your first sexual experi like ?
# 14        what are the law to chang your status from a s...
# 15        what would a trump presid mean for current int...
# 16                                  what doe manipul mean ?
# 17        whi do girl want to be friend with the guy the...
# 18        whi are so mani quora user post question that ...
# 19        which is the best digit market institut in ban...
# 20                               whi do rocket look white ?
# 21                      what 's caus someon to be jealous ?
# 22          what are the question should not ask on quora ?
# 23                                how much is 30 kv in hp ?
# 24        what doe it mean that everi time i look at the...
# 25        what are some tip on make it through the job i...
# 26                                     what is web applic ?
# 27             doe societi place too much import on sport ?
# 28                   what is best way to make money onlin ?
# 29                   how should i prepar for ca final law ?
#                                 ...
# 404260                    which phone is best under 12000 ?
# 404261    who is the overal most popular game of throne ...
# 404262           how do you troubleshoot a toshiba laptop ?
# 404263    how doe the burn of fossil fuel contribut to g...
# 404264    is it safe to store an extern batteri power ba...
# 404265                   how can i gain weight on my bodi ?
# 404266    what is the green dot next to the phone icon o...
# 404267    what are the caus of the fall of the roman emp...
# 404268    whi do n't we still do great music like in the...
# 404269          how do you diagnos antisoci person disord ?
# 404270             what is the differ between who and how ?
# 404271    doe stalin have ani grandchild that are still ...
# 404272    what are the best new car product or invent th...
# 404273       what happen if you put milk in a coffe maker ?
# 404274    will the next generat of parent chang or stay ...
# 404275    in account , whi do we debit expens and credit...
# 404276                          what is copilotsearch.com ?
# 404277                                 what doe analyt do ?
# 404278             how did you prepar for aiim neet/aipmt ?
# 404279    what is the minimum time requir to build a fly...
# 404280    what are some outfit idea to wear to a frat pa...
# 404281    whi is manaphi childish in pokmon ranger and t...
# 404282           how doe a long distanc relationship work ?
# 404283    what do you think of the remov of the magsaf c...
# 404284                what doe jainism say about homosexu ?
# 404285    how mani keyword are there in the racket progr...
# 404286            do you believ there is life after death ?
# 404287                                   what is one coin ?
# 404288    what is the approx annual cost of live while s...
# 404289               what is like to have sex with cousin ?
# Name: cleaned_question1, dtype: object

# %%
train_df[(train_df['question1'].str.contains('\[math\]')) & (train_df.is_duplicate) == 1].sample().values
# Out:
# array([[120855, 195960, 195961,
#         'How would you simplify [math]i^{100}[/math]?',
#         'How do I simplify i\xe2\x88\xa7100?', 1]], dtype=object)

# %%
train_df[(train_df['question1'].str.contains('\[math\]')) & (train_df.is_duplicate == 0)].sample().values
# Out:
# array([[184627, 101978, 282026,
#         'How do I integrate [math]\\displaystyle\\int_{\\frac\\pi6}^{\\frac\\pi4}\\sqrt{1-\\cos2x}\\,dx[/math]?',
#         'How can I integrate [math] \\int_{0}^{\\frac{\\pi}{4}} \\ln(1+\\tan(x)) dx [/math]?',
#         0]], dtype=object)

# %%
train_df[(train_df['question2'].apply(lambda text: is_ascii(text)) == False) & (train_df['is_duplicate']==1)]
# Out:
#             id    qid1    qid2  \
# 120        120     241     242
# 176        176     353     354
# 199        199     399     400
# 307        307     614     615
# 721        721    1438    1439
# 791        791    1577    1578
# 907        907    1809    1810
# 1141      1141    2274    2275
# 1452      1452    2892    2893
# 1530      1530    3047    3048
# 2597      2597    5160    5161
# 3539      3539    7012    7013
# 3544      3544    7021    7022
# 3691      3691    7311    7312
# 3807      3807    7541    7542
# 3999      3999    7918    7919
# 4303      4303    8509    8510
# 4489      4489    8872    8873
# 4874      4874    9620    9621
# 4942      4942    9748    9749
# 5825      5825   11438   11439
# 6144      6144   12044   12045
# 6244      6244   12241    9661
# 6860      6860   13426   13427
# 7140      7140   13959   13960
# 7154      7154   13987   13988
# 7227      7227    3349   14129
# 7587      7587   14816   14817
# 7646      7646   14930   14931
# 7674      7674   14982   14983
# ...        ...     ...     ...
# 396652  396652  291140  217131
# 396908  396908  156319  152316
# 396996  396996   83341  267197
# 397268  397268    3768   35549
# 397390  397390   55388   19678
# 397710  397710   15766   65980
# 397811  397811   11698   90061
# 398315  398315  345634  154217
# 398405  398405  531631  531632
# 398598  398598  531828  531829
# 399708  399708   13216   69862
# 399964  399964  533285  533286
# 400095  400095   74602    1439
# 400102  400102  533437   50540
# 400131  400131  533465  533466
# 400454  400454  186538   36354
# 400579  400579  146562  284890
# 400585  400585   13373   14931
# 400653  400653   17589   62668
# 401071  401071  357700  325124
# 401108  401108   64324   38395
# 401283  401283   78416   67387
# 401314  401314  249772    9621
# 401746  401746   89824   96515
# 401968  401968  142978  123003
# 402148  402148  172269  131331
# 402305  402305  535775  535776
# 403243  403243    4114  189245
# 403400  403400  536978  536979
# 403696  403696  129519  242137
#
#                                                 question1  \
# 120     Why my question was marked as needing imrovement?
# 176                   What is it like to live in Cologne?
# 199     What are the effects of demonitization of 500 ...
# 307     What job possibilities exist for a Bachelors i...
# 721     How does Quora quickly mark questions as needi...
# 791                          What is the Hizmet movement?
# 907     What is your view on the recent demonetization...
# 1141    What is the best way for a native Chinese spea...
# 1452    How do you view the Indian government's decisi...
# 1530      How long will the Pokémon GO "fever" will last?
# 2597    I told a girl that's in a relationship that I ...
# 3539              Can you change your team on Pokemon Go?
# 3544    When was the last year that America was great ...
# 3691    How will the ban of 1000 and 500 rupee notes a...
# 3807    How can I prove that (A × B) − (C × D) = (A − ...
# 3999                               How can learn English?
# 4303    Which are the positive benefits of banning exi...
# 4489    What are the safety precautions on handling sh...
# 4874    What are Hillary's qualifications to be presid...
# 4942    What prevented Harry Potter from becoming an O...
# 5825      What is decanting? How is it used in chemistry?
# 6144                  What is a Bose-Einstein condensate?
# 6244    What would be your New Year resolutions for 2017?
# 6860                             Why shouldn't I suicide?
# 7140    If I have an idea for a video game can I sell ...
# 7154    Can earth's magnetic field be used to produce ...
# 7227    Is it true that the new Rs. 2000 currency note...
# 7587               How do I hack a mobile phone remotely?
# 7646    What are your views on banning 500 and 1000 ru...
# 7674    Mrs. Clinton: What are your goals/plans for NA...
# ...                                                   ...
# 396652  How is Flipkart selling One plus 3 (at low cos...
# 396908   What are the best smartphones under 15K in 2016?
# 396996                          How do I play Pokémon GO?
# 397268                     Which phone is best under 15k?
# 397390                      Why is Pokémon GO so popular?
# 397710  What is your new year resolution for 2017 or g...
# 397811  Can a person be in love with two persons at a ...
# 398315  Why does Quora say that my question needs impr...
# 398405  Was Chérif Kouachi in the Paris murder spree a...
# 398598  Will Trump lose Wisconsin's electoral votes if...
# 399708  What do you think about RBI's new move of bann...
# 399964   What is your favorite legendary pokemon and why?
# 400095  How does Quora mark questions as "needing impr...
# 400102            Why aren't cats mentioned in the Bible?
# 400131  The nucleus of an atom is found out to have a ...
# 400454  If you knew you were going to die tomorrow, wh...
# 400579                Why does eye color change with age?
# 400585  What is your view on the move to scrap 500 and...
# 400653  What are the safety precautions on handling sh...
# 401071  What would be impact of 500 & 1000 rs ban in I...
# 401108  What's the most embarrassing moment you've eve...
# 401283  What are the safety precautions on handling sh...
# 401314      Is Hillary Clinton qualified to be President?
# 401746  Is interface theory of perception by Donald Ho...
# 401968  In Pokemon Ranger and The Temple of The Sea, W...
# 402148  I never signed up for this Quora account. How ...
# 402305  Which dating site has the most customization t...
# 403243  How can we trace a phone call's origin or cell...
# 403400  Do both  the Shias and Sunnis discriminate aga...
# 403696                Why shouldn't I visit your country?
#
#                                                 question2  is_duplicate
# 120     How can I ask a question without getting marke...             1
# 176            What is it like to live in Köln, Germany?              1
# 199     What will be the impact of scrapping of ₹500 a...             1
# 307     What jobs are available with a bachelor’s degr...             1
# 721     Why does Quora mark my questions as needing im...             1
# 791                           What is the Gülen movement?             1
# 907     What are your views on demonetization of ₹500 ...             1
# 1141    How can I learn English well as a Chinese stud...             1
# 1452    What are going to be the rammifications of the...             1
# 1530    How long you thing this Pokémon GO trend will ...             1
# 2597    I told a girl who has a boyfriend that I liked...             1
# 3539               Can you change the team in Pokémon GO?             1
# 3544    When was the last time America was great accor...             1
# 3691    How will discontinuing ₹500 and ₹1000 notes af...             1
# 3807    How can I prove (A × B) − (C × D) = (A − C) × ...             1
# 3999                       How can I learn English well？?             1
# 4303    Will the economy of India collapse due to the ...             1
# 4489    What are the safety precautions on handling sh...             1
# 4874    What are Hillary Clinton’s qualifications to b...             1
# 4942              Why wasn't Harry Potter an Obscurial? ﻿             1
# 5825                    What is “decanting” in chemistry?             1
# 6144    What is a Bose–Einstein condensate? What is th...             1
# 6244             What are your new year resolutions’2017?             1
# 6860                    Why shouldn’t you commit suicide?             1
# 7140    I have come up with a video game idea with a p...             1
# 7154    Why can’t we use earths magnetic field to prod...             1
# 7227    How the nano GPS chips (NGC) in Indian 2000 Ru...             1
# 7587        How do I hack a victim’s mobile without help?             1
# 7646    How do you see the PM Modi’s move of banning o...             1
# 7674    What are Hillary Clinton’s plans on funding th...             1
# ...                                                   ...           ...
# 396652  How can Flipkart afford to sell One Plus 3 at ...             1
# 396908  Which is the best android device to buy under ...             1
# 396996                        How can we play Pokémon GO?             1
# 397268         Which phone would be the best for ₹15,000?             1
# 397390                  What makes Pokémon GO so popular?             1
# 397710           What is your 2017 New Year’s resolution?             1
# 397811  İs it possible to be in love with 2 people at ...             1
# 398315  Why does Quora send me a notification that my ...             1
# 398405  Was Chérif Kouachi in the Paris murder spree a...             1
# 398598  Will Wisconsin’s votes be voided if it doesn't...             1
# 399708  What do you think about banning ₹500 and ₹1000...             1
# 399964   What is your favorite legendary Pokémon and why?             1
# 400095  Why does Quora mark my questions as needing im...             1
# 400102            Why aren’t cats mentioned in the Bible?             1
# 400131  The nucleus of an atom is found out to have a ...             1
# 400454  ’what would you do if you knew you would die t...             1
# 400579       Why does people’s eye color change with age?             1
# 400585  How do you see the PM Modi’s move of banning o...             1
# 400653  What are the safety precautions on handling sh...             1
# 401071  What will be the impact of the banning ₹1000 a...             1
# 401108  What’s the most embarrassing moment of your li...             1
# 401283  What are the safety precautions on handling fi...             1
# 401314  What are Hillary Clinton’s qualifications to b...             1
# 401746  Is Donald Hoffman’s interface theory of percep...             1
# 401968  Why did Manaphy had a panic attack in Pokémon ...             1
# 402148   Can’t delete my Quora account, what should I do?             1
# 402305  Which dating app is the most customizable to f...             1
# 403243           How do I find a phone number’s location?             1
# 403400  Why do Muslims discriminate against Bahà'i faith?             1
# 403696                Why shouldn’t I visit your country?             1
#
# [1434 rows x 6 columns]

# %%
s = '4cos\xc2\xb2\xce\xb8+4sec\xc2\xb2\xce\xb8=5'
s = 'When do you use シ instead of し'

# %%
tokenize('Vinyl-Leather-Rubber')
# Out:
# u'vinyl-leather-rubb'

# %%
tokenize(clean_unicode('4cos\xc2\xb2\xce\xb8+4sec\xc2\xb2\xce\xb8=5'))
# Out:
# u'4cos+4sec=5'
